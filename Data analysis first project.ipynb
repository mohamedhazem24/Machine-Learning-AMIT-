# %% [markdown]
# # First Data analysis assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('auto_mpg_dataset.csv')
df.head(20)
# Out:
#     cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0           8         307.0       130.0  3504.0          12.0          70
# 1           8         350.0       165.0  3693.0          11.5          70
# 2           8         318.0       150.0  3436.0          11.0          70
# 3           8         304.0       150.0  3433.0          12.0          70
# 4           8         302.0       140.0  3449.0          10.5          70
# 5           8         429.0       198.0  4341.0          10.0          70
# 6           8         454.0       220.0  4354.0           9.0          70
# 7           8         440.0       215.0  4312.0           8.5          70
# 8           8         455.0       225.0  4425.0          10.0          70
# 9           8         390.0       190.0  3850.0           8.5          70
# 10          8         383.0       170.0  3563.0          10.0          70
# 11          8         340.0       160.0  3609.0           8.0          70
# ...

# %%
df.shape
# Out:
# (398, 9)

# %%
len(df['car_name'].unique())
# Out:
# 305

# %%
for i in df.columns:
    plt.figure()
    plt.hist(df[i])
    plt.xlabel(i)
    plt.show()

# %% [markdown]
# ###  after visualising the data

# %% [markdown]
# #### 1-horsepower column has outliers of value -10000
# #### 2-other data seems more resonable and some of them are normally distrubuted
# #### 3- the cylinders column contains small amount of cars with 3 cylinders and 5 cylinders
# #### which seemed reasonable because odd number of cylinders lacks of balance and physical equivalence

# %%
plt.figure()
plt.hist(df['cylinders'])
plt.xlabel("cylinders")
plt.show()

# %% [markdown]
# ## figure 1
# ![image.png](attachment:image.png)
# ### as you can see in that figure (figure 1) that the cylinders does not move in a harmony and symmetric way
# # --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## figure 2
# ![image.png](attachment:image.png)
# ## as you can see in that figure (figure 2) that the cylinders moves in a harmony and symmetric way
# # --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### now we will try to figure out a way  to replace those outliers with real values instead of dropping them

# %%
df['horsepower'].unique()
# Out:
# array([ 1.30e+02,  1.65e+02,  1.50e+02,  1.40e+02,  1.98e+02,  2.20e+02,
#         2.15e+02,  2.25e+02,  1.90e+02,  1.70e+02,  1.60e+02,  9.50e+01,
#         9.70e+01,  8.50e+01,  8.80e+01,  4.60e+01,  8.70e+01,  9.00e+01,
#         1.13e+02,  2.00e+02,  2.10e+02,  1.93e+02, -1.00e+05,  1.00e+02,
#         1.05e+02,  1.75e+02,  1.53e+02,  1.80e+02,  1.10e+02,  7.20e+01,
#         8.60e+01,  7.00e+01,  7.60e+01,  6.50e+01,  6.90e+01,  6.00e+01,
#         8.00e+01,  5.40e+01,  2.08e+02,  1.55e+02,  1.12e+02,  9.20e+01,
#         1.45e+02,  1.37e+02,  1.58e+02,  1.67e+02,  9.40e+01,  1.07e+02,
#         2.30e+02,  4.90e+01,  7.50e+01,  9.10e+01,  1.22e+02,  6.70e+01,
#         8.30e+01,  7.80e+01,  5.20e+01,  6.10e+01,  9.30e+01,  1.48e+02,
#         1.29e+02,  9.60e+01,  7.10e+01,  9.80e+01,  1.15e+02,  5.30e+01,
#         8.10e+01,  7.90e+01,  1.20e+02,  1.52e+02,  1.02e+02,  1.08e+02,
#         6.80e+01,  5.80e+01,  1.49e+02,  8.90e+01,  6.30e+01,  4.80e+01,
# ...

# %%
df[df['horsepower']<0].index
df.iloc[df[df['horsepower']<0].index]
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 32           4          98.0   -100000.0  2046.0          19.0          71
# 126          6         200.0   -100000.0  2875.0          17.0          74
# 330          4          85.0   -100000.0  1835.0          17.3          80
# 336          4         140.0   -100000.0  2905.0          14.3          80
# 354          4         100.0   -100000.0  2320.0          15.8          81
# 374          4         151.0   -100000.0  3035.0          20.5          82
#
#      origin              car_name   mpg
# 32        1            ford pinto  25.0
# 126       1         ford maverick  21.0
# 330       2  renault lecar deluxe  40.9
# 336       1    ford mustang cobra  23.6
# 354       2           renault 18i  34.5
# 374       1        amc concord dl  23.0

# %%
df[df['car_name'].str.startswith('ford')].index
# Out:
# Int64Index([  4,   5,  17,  25,  32,  36,  40,  43,  48,  61,  65,  74,  80,
#              88,  92, 100, 104, 112, 126, 130, 136, 139, 155, 159, 166, 168,
#             174, 190, 193, 200, 206, 214, 228, 232, 236, 245, 254, 255, 264,
#             282, 286, 290, 314, 336, 351, 352, 365, 373, 389, 393, 396],
#            dtype='int64')

# %% [markdown]
# ### we tried to figure out if these outliers related to specific car models

# %%
df.iloc[df[df['car_name'].str.startswith('ford pinto')].index]
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 32           4          98.0   -100000.0  2046.0          19.0          71
# 61           4         122.0        86.0  2226.0          16.5          72
# 80           4         122.0        86.0  2395.0          16.0          72
# 112          4         122.0        85.0  2310.0          18.5          73
# 130          4         122.0        80.0  2451.0          16.5          74
# 168          4         140.0        83.0  2639.0          17.0          75
# 174          6         171.0        97.0  2984.0          14.5          75
# 206          4         140.0        72.0  2565.0          13.6          76
#
#      origin             car_name   mpg
# 32        1           ford pinto  25.0
# 61        1  ford pinto runabout  21.0
# 80        1      ford pinto (sw)  22.0
# 112       1           ford pinto  19.0
# 130       1           ford pinto  26.0
# 168       1           ford pinto  23.0
# ...

# %% [markdown]
# ### then we found it is not related to car_name so we tried to replace them by their real values after searching it up in google

# %%
c=0
arr=[75,140,53.5,120,81,82] ## this array has real horse power values of the cars with-10000 horsepower in order according to index
for i in df[df['horsepower']<0].index:
    df.iloc[i,2]=arr[c]
    c=c+1

# %% [markdown]
# ## then we checked the distribution of cars horse power after fixing the value =so fhorse power outliers

# %%
plt.figure()
plt.hist(df['horsepower'])
plt.xlabel('horsepower')
plt.show()

# %% [markdown]
# ## now the distribution of the horsepower data seems reasonable

# %%
df.describe()
# Out:
#         cylinders  displacement  horsepower       weight  acceleration  \
# count  398.000000    398.000000  398.000000   398.000000    398.000000
# mean     5.454774    193.425879  104.280151  2970.424623     15.568090
# std      1.701004    104.269838   38.396874   846.841774      2.757689
# min      3.000000     68.000000   46.000000  1613.000000      8.000000
# 25%      4.000000    104.250000   75.000000  2223.750000     13.825000
# 50%      4.000000    148.500000   92.500000  2803.500000     15.500000
# 75%      8.000000    262.000000  125.000000  3608.000000     17.175000
# max      8.000000    455.000000  230.000000  5140.000000     24.800000
#
#        model_year      origin         mpg
# count  398.000000  398.000000  398.000000
# mean    76.010050    1.572864   23.514573
# std      3.697627    0.802055    7.815984
# min     70.000000    1.000000    9.000000
# 25%     73.000000    1.000000   17.500000
# 50%     76.000000    1.000000   23.000000
# ...

# %%
df[df['cylinders']==3]
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 71           3          70.0        97.0  2330.0          13.5          72
# 111          3          70.0        90.0  2124.0          13.5          73
# 243          3          80.0       110.0  2720.0          13.5          77
# 334          3          70.0       100.0  2420.0          12.5          80
#
#      origin         car_name   mpg
# 71        3  mazda rx2 coupe  19.0
# 111       3        maxda rx3  18.0
# 243       3       mazda rx-4  21.5
# 334       3    mazda rx-7 gs  23.7

# %%
df.iloc[df[df['car_name'].str.startswith('mazda rx')].index]
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 71           3          70.0        97.0  2330.0          13.5          72
# 243          3          80.0       110.0  2720.0          13.5          77
# 334          3          70.0       100.0  2420.0          12.5          80
#
#      origin         car_name   mpg
# 71        3  mazda rx2 coupe  19.0
# 243       3       mazda rx-4  21.5
# 334       3    mazda rx-7 gs  23.7

# %%
df[df['cylinders']==5]
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 274          5         131.0       103.0  2830.0          15.9          78
# 297          5         183.0        77.0  3530.0          20.1          79
# 327          5         121.0        67.0  2950.0          19.9          80
#
#      origin             car_name   mpg
# 274       2            audi 5000  20.3
# 297       2   mercedes benz 300d  25.4
# 327       2  audi 5000s (diesel)  36.4

# %%
df.iloc[df[df['car_name'].str.startswith('mercedes')].index]
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 211          6         168.0       120.0  3820.0          16.7          76
# 297          5         183.0        77.0  3530.0          20.1          79
# 328          4         146.0        67.0  3250.0          21.8          80
#
#      origin            car_name   mpg
# 211       2  mercedes-benz 280s  16.5
# 297       2  mercedes benz 300d  25.4
# 328       2  mercedes-benz 240d  30.0

# %% [markdown]
# # now we will try to know more about the relation between the features

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## according to that data we can notice
# ### 1- Some features are moderatly correlated with mpg and some are highly correlated with mpg and that good for  predictions models
# ### 2- that cylinders ,horsepower ,displacement and wieghts increment are inversly related to mpg in high correlation
# ### 3-that origin is not highly correlated with mpg cause it does not depend on origin too much cause you can manifacture a car in an origin of known high quality but the car mpg is not good
# ### 4-the acceleration doesnot have high correlation with any of the other features cause it has small range
# ### 6- the most correlated feature with model year is mpg so we can conclude that the mpg is the most they worked on developing it among the other features
# ### 7-The most correlated feature with displacement is the number of cylinders cause the equation formula of displacment is (π x (radius)2 x stroke x number of cylinders)

# %%
plt.figure()
plt.scatter(df['mpg'],df['model_year'])
plt.xlabel('mpg')
plt.ylabel('model_year')
plt.show()

# %%
plt.figure()

plt.scatter(df['weight'],df['model_year'])
plt.xlabel('weight')
plt.ylabel('model_year')
plt.show()

# %%
plt.figure()

plt.scatter(df['horsepower'],df['model_year'])
plt.xlabel('horsepower')
plt.ylabel('model_year')
plt.show()

# %% [markdown]
# ## according to the above 3 graphs we conclouded that
# ### 1-In 1980 the improvment of cars took a high leap
# ### 2-1982 was a big revloution in the manifacturing of cars  by increasing the mpg through decremnet of weight and horse power

# %%
df['Brands']=df['car_name'].str.split(expand=True).iloc[:,0]

# %%
df['Brands'].unique()
# Out:
# array(['chevrolet', 'buick', 'plymouth', 'amc', 'ford', 'pontiac',
#        'dodge', 'toyota', 'datsun', 'volkswagen', 'peugeot', 'audi',
#        'saab', 'bmw', 'chevy', 'hi', 'mercury', 'opel', 'fiat',
#        'oldsmobile', 'chrysler', 'mazda', 'volvo', 'renault', 'toyouta',
#        'maxda', 'honda', 'subaru', 'chevroelt', 'capri', 'vw',
#        'mercedes-benz', 'cadillac', 'mercedes', 'vokswagen', 'triumph',
#        'nissan'], dtype=object)

# %%
df['Brands'].replace({'toyouta':'toyota','vw':'volkswagen','maxda':'mazda','mercedes':'mercedes-benz','vokswagen':'volkswagen','chevroelt':'chevrolet'},inplace=True)

# %%
df
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0  3504.0          12.0          70
# 1            8         350.0       165.0  3693.0          11.5          70
# 2            8         318.0       150.0  3436.0          11.0          70
# 3            8         304.0       150.0  3433.0          12.0          70
# 4            8         302.0       140.0  3449.0          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0  2790.0          15.6          82
# 394          4          97.0        52.0  2130.0          24.6          82
# 395          4         135.0        84.0  2295.0          11.6          82
# 396          4         120.0        79.0  2625.0          18.6          82
# 397          4         119.0        82.0  2720.0          19.4          82
#
#      origin                   car_name   mpg      Brands
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.pivot_table(values='mpg',index='model_year',columns=['Brands']).replace(np.nan,0),annot=True)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mmsc=MinMaxScaler()
df['weight']=mmsc.fit_transform(np.array(df['weight']).reshape( 398,1))
plt.figure(figsize=(15,10))
sns.heatmap(df.pivot_table(values='weight',index='model_year',columns=['Brands']).replace(np.nan,0),annot=True)
plt.show()

# %% [markdown]
# ## we noticed some info in our data :
# ### 1- there was is decreament in mpg in 1972 due to increament of wieght in 1972
# ### 2- that volkswagen had the best mpg and the least weight

# %%
plt.hist(df[df['origin']==1]['mpg'],histtype='step',color='blue')
plt.hist(df[df['origin']==2]['mpg'],histtype='step',color='green')
plt.hist(df[df['origin']==3]['mpg'],histtype='step',color='red')
# Out:
# (array([ 5.,  6., 11.,  8., 17., 16., 10.,  4.,  0.,  2.]),
#  array([18.  , 20.86, 23.72, 26.58, 29.44, 32.3 , 35.16, 38.02, 40.88,
#         43.74, 46.6 ]),
#  [<matplotlib.patches.Polygon at 0x22070092040>])

# %% [markdown]
# ### we noticed that
# ### 1-  the origin 1 has biggest participation in the market
# ### 2 - despite origin 1 has the biggest participation but origin 3 the best quality in tha market  and that gives us a ### conclusion that origin 3 market has hard condtions to build up a car company compared to origin 1 as origin have lots of cars of low quality cars but origin 3 does  not have cars with low quality mpg cars

# %%
plt.hist(df[df['origin']==1]['weight'],histtype='step',color='blue')
plt.hist(df[df['origin']==2]['weight'],histtype='step',color='green')
plt.hist(df[df['origin']==3]['weight'],histtype='step',color='red')
# Out:
# (array([ 2.,  8., 14., 14., 10., 10.,  6.,  6.,  3.,  6.]),
#  array([0.        , 0.03734052, 0.07468103, 0.11202155, 0.14936206,
#         0.18670258, 0.2240431 , 0.26138361, 0.29872413, 0.33606464,
#         0.37340516]),
#  [<matplotlib.patches.Polygon at 0x22070405940>])

# %% [markdown]
# ## we noticed that:
# ### 1- The cars from origin 1 has a lack of good raw metals for manifacturing cars
# ### 2- The cars of origin 3 has the least weight raw metals

# %%
plt.hist(df[df['origin']==1]['cylinders'],histtype='step',color='blue')
plt.hist(df[df['origin']==2]['cylinders'],histtype='step',color='green')
plt.hist(df[df['origin']==3]['cylinders'],histtype='step',color='red')
# Out:
# (array([ 4.,  0.,  0., 69.,  0.,  0.,  0.,  0.,  0.,  6.]),
#  array([3. , 3.3, 3.6, 3.9, 4.2, 4.5, 4.8, 5.1, 5.4, 5.7, 6. ]),
#  [<matplotlib.patches.Polygon at 0x2207011a700>])

# %% [markdown]
# ### 3- the cars of origin 1 are the only ones with 8 cylinders because most of them had high weights compared to the other origins

# %%
plt.hist(df[df['origin']==1]['horsepower'],histtype='step',color='blue')
plt.hist(df[df['origin']==2]['horsepower'],histtype='step',color='green')
plt.hist(df[df['origin']==3]['horsepower'],histtype='step',color='red')
# Out:
# (array([ 5., 21., 20.,  0.,  7., 18.,  2.,  2.,  3.,  1.]),
#  array([ 52.,  60.,  68.,  76.,  84.,  92., 100., 108., 116., 124., 132.]),
#  [<matplotlib.patches.Polygon at 0x2206feb18e0>])

# %% [markdown]
# ## we conclude at the end that cars with :
# ### Origin 1:built in USA cause the USA are famous for their horse power
# ### Origin 2:built in Europe cause Europe participate in the market with only balanced specs
# ### Origin 3:built in ASIA cause ASIA are famous for having lots of raw materials
